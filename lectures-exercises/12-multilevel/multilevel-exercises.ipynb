# %%
## This is not an exhaustive list of the import you may need, if needed include more
import os
import numpy as np
import pandas as pd
import arviz as az
import pymc as pm
import matplotlib.pyplot as plt

# %% [markdown]
# __Probabilistic Programming. Wasowski. Pardo. IT University of Copenhagen__
#
# This file contains the list of exercises for the week, as well as any related code.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 13E1
#
# There is no need for coding in this exercise. It is only necessary to provide an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 13E2
#
# There is no need for coding in this exercise. It is only necessary to provide the new model and an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 13E3
#
# There is no need for coding in this exercise. It is only necessary to provide an the new model and an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 13E4
#
# There is no need for coding in this exercise. It is only necessary to provide an the new model and an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 13E5
#
# There is no need for coding in this exercise. It is only necessary to provide an the new model and an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 13M1
#
# You can find the data file in the `Data/reedfrogs.csv`.
#
# The predictors that the exercise asks to add do not need to be part of the multilevel aspects of the model. You should add them first separately as regular predictors, then together and finally in an interaction parameter (all of these cases in a non-multilevel style). Furthermore, the "inferred variation" across tanks refers to the high level $\sigma$ for the tanks intercepts.
#
# The cell below loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %%
pd.read_csv("Data/reedfrogs.csv", sep=";")

# %% [markdown]
# ## Exercise 13M2
#
# You should use the models in exercise **13M1** for this exercise.
#
# You can use the cell below or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 13M3
#
# For this exercise, recall that the Cauchy distribution is included in PyMC as `pm.Cauchy(...)`.
#
# The cell in exercise **13M1** above loads the data. You can use the cell below or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 13M4
#
# For this exercise, recall that the Student-t distribution is included in PyMC as `pm.StudentT(...)`.
#
# The cell in exercise **13M1** above loads the data. You can use the cell below or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 13M5
#
# You can find the data file in the `Data/chimpanzees.csv`.
#
# The cell above loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %%
pd.read_csv("Data/chimpanzees.csv", sep=";")

# %% [markdown]
# ## Exercise 13H2
#
# You can find the data file in the `Data/Trolley.csv`.
#
# The cell below loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %%
dfb = pd.read_csv("Data/Trolley.csv", sep=";")
dfb
