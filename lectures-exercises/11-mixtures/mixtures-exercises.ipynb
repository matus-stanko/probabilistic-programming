# %%
## This is not an exhaustive list of the import you may need, if needed include more
import os
import numpy as np
import pandas as pd
import arviz as az
import pymc as pm
import matplotlib.pyplot as plt

# %% [markdown]
# __Probabilistic Programming. Wasowski. Pardo. IT University of Copenhagen__
#
# This file contains the list of exercises for the week, as well as any related code.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Dirichlet bonus material
#
# If you have not worked before with the Dirichlet distribution, we recommend studying the notebook in `110-mixtures/dirichlet-bonus-material/`.
#
# ### Exercise 1
#
# The folder mentioned above contains the notebook `110-mixtures/dirichlet-bonus-material/ex-expected-revenue.ipynb` with an exercise specifically designed to use the Dirichlet distribution. The exercise involves a Bayesian version of A/B testing. More technically, they exercise requires the use of a Dirichlet prior and multinomial likelihood.

# %% [markdown]
# ## Exercise 12E1
#
# There is no need for coding in this exercise. It is only necessary to provide an explanation and example. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12E2
#
# There is no need for coding in this exercise. It is only necessary to provide an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12E3
#
# There is no need for coding in this exercise. It is only necessary to provide an explanation. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12E4
#
# There is no need for coding in this exercise. It is only necessary to provide the examples. You may use the Markdown cell below to write your answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12M1
#
# Compute the answer to the exercise in the cell below, and discuss the answer.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12M2
#
# Compute the answer to the exercise in the cell below.

# %% [markdown]
# ## Exercise 12M3
#
# There is no need for coding in this exercise. You must provide the definition that the exercise requests. You may use the Markdown cell below to write your answer. You may use the LaTeX mathematical's environment to write equations. The material on the lecture notebook about Zero-Inflated models may be useful as a reference for this exercise.

# %% [markdown]
# */Your written answer here/*

# %% [markdown]
# ## Exercise 12H1
#
# You can find the data file in the `Data/Hurricanes.csv`. You may find inspiration in the Islands and Tools model that we considered in the last lecture (and also briefly in this lecture).
#
# The cell below loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %%
pd.read_csv(os.path.join("Data", "Hurricanes.csv"), delimiter=";")

# %% [markdown]
# ## Exercise 12H2
#
# You can find the data file in the `Data/Hurricanes.csv`. You may find inspiration in the Gamma-Poisson models that we consider in this lecture `m11_11`.
#
# The cell above loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 12H3
#
# You can find the data file in the `Data/Hurricanes.csv`. As before, you may find inspiration in the Gamma-Poisson models that we consider in this lecture `m11_11`. We do not have the information about the description of the predictors `damage_norm` and `min_pressue`. Nevertheless, you may treat these as metric variables. With this choice, you may solve the intended goal of the exercise, which is the study the interaction between these predictors and `femininity`.
#
# The cell above loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 12H4
#
# You can find the data file in the `Data/Hurricanes.csv`. As before, you may find inspiration in the Gamma-Poisson models that we consider in this lecture `m11_11`, and your solutions to exercise **12H3**.
#
# The cell above loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %% [markdown]
# ## Exercise 12H5
#
# You can find the data file in the `Data/Trolley.csv`. You may find useful model `m12_4` from the lecture notebook to solve this exercise.
#
# The cell below loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.

# %%
pd.read_csv(os.path.join("Data", "Trolley.csv"), delimiter=";")

# %% [markdown]
# ## Exercise 12H7
#
# You can find the data file in the `Data/Trolley.csv`. As before, you may find useful model `m12_4` from the lecture notebook to solve this exercise. This exercise requires causal reasoning. Thus, you may want to revisit the chapters on causal reasoning: Chp. 5 and especially Chp. 6.
#
# The cell above loads the data. You may extend the cell or create new ones below to write your solution to the exercise.
#
# The discussion could go on a Markdown cell after the code.
